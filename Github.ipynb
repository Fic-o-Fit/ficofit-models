# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ml-gdrive/
# Out:
# /content/drive/MyDrive/ml-gdrive

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ml-gdrive/.git/

# %%
# !git remote rm origin

# %%
# !git remote add origin https://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@github.com/Fic-o-Fit/ml-gdrive.git

# %%
# !git add .

# %%
# !git config --global user.email "deesetyaptr@gmail.com"
# !git config --global user.name "Deandra Setya"

# %%
# !git commit -m "ml progress on gdrive"
# Out:
# [main ed3323b] ml progress on gdrive
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Counting objects: 897, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (897/897), done.
# Writing objects: 100% (897/897), 57.58 MiB | 10.53 MiB/s, done.
# Total 897 (delta 20), reused 0 (delta 0)
# remote: Resolving deltas: 100% (20/20), done.
# To https://github.com/Fic-o-Fit/ml-gdrive.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
