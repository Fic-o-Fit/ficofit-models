# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ml-gdrive/
# Out:
# /content/drive/MyDrive/ml-gdrive

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/ml-gdrive/.git/

# %%
# !git remote add origin https://{git_token}@github.com/Fic-o-Fit/ml-gdrive.git

# %%
# !git add .

# %%
# !git config --global user.email "deesetyaptr@gmail.com"
# !git config --global user.name "Deandra Setya"

# %%
# !git commit -m "ml progress on gdrive"

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# fatal: could not read Password for 'https://{git_token}@github.com': No such device or address
